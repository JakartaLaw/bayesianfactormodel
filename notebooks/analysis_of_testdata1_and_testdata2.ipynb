# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import seaborn as sbn

# %%
from notebookutils import root_dir, corr_plot; root_dir()
# Out:
# now in dir:  /Users/Jeppe/Projects/BayesFactorModel

# %%
from model.utils import read_party_keys, party_name_from_key
from model.distributionplotter import DistributionPlotter
from model.traceplotter import TracePlotter
from model.parameterframe import ParameterFrame
from model.parameters import Parameters
from model.plotter import Plotter

# %%
plt.rcdefaults()

# %% [markdown]
# # Testdata 1

# %%
beta_trace = pd.read_pickle("data//testdata1_beta_trace_df.pkl")
sigma_trace = pd.read_pickle("data//testdata1_sigma_trace_df.pkl")
factor_trace = pd.read_pickle("data//testdata1_factor_trace_df.pkl")

# %%
tp = TracePlotter(sigma_trace)
f = tp.plot_diagonal_traces()
f.savefig('figs//testdata1_trace_sigma_plot.png')
f

# %%
tp = TracePlotter(beta_trace)
f = tp.plot_4x4_traces()
f.savefig('figs//testdata1_trace_beta_plot.png')
f

# %% [markdown]
# # Testdata 2

# %%
beta_trace = pd.read_pickle("data//testdata2_beta_trace_df.pkl")
sigma_trace = pd.read_pickle("data//testdata2_sigma_trace_df.pkl")
factor_trace = pd.read_pickle("data//testdata2_factor_trace_df.pkl")

# %%
tp = TracePlotter(sigma_trace)
f = tp.plot_diagonal_traces()
f.savefig('figs//testdata2_trace_sigma_plot.png')
f

# %%
tp = TracePlotter(beta_trace)
f = tp.plot_4x4_traces()
f.savefig('figs//testdata2_trace_beta_plot.png')
f
